# %%
import pandas

# %%
from sklearn.tree import DecisionTreeClassifier as dtree
from sklearn.model_selection import train_test_split as tts
from sklearn import metrics
from sklearn.tree import export_graphviz
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus
import numpy as np
import matplotlib.pyplot as plt

# %%
feature_labels= ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']

# %%
diabetes_data = pandas.read_csv("/home/hadi/python_data/diabetes_data/diabetes.csv", header=None, skiprows=[0], names= feature_labels)

# %%
diabetes_data.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %%
type(diabetes_data)
# Out:
# pandas.core.frame.DataFrame

# %%
y = diabetes_data.label

# %%
features = feature_labels.copy()

# %%
features.remove("label")

# %%
features
# Out:
# ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age']

# %%
x = diabetes_data[features]

# %%
l_features
# Out:
#      pregnant  glucose  bp  skin  insulin   bmi  pedigree  age
# 0           6      148  72    35        0  33.6     0.627   50
# 1           1       85  66    29        0  26.6     0.351   31
# 2           8      183  64     0        0  23.3     0.672   32
# 3           1       89  66    23       94  28.1     0.167   21
# 4           0      137  40    35      168  43.1     2.288   33
# ..        ...      ...  ..   ...      ...   ...       ...  ...
# 763        10      101  76    48      180  32.9     0.171   63
# 764         2      122  70    27        0  36.8     0.340   27
# 765         5      121  72    23      112  26.2     0.245   30
# 766         1      126  60     0        0  30.1     0.349   47
# 767         1       93  70    31        0  30.4     0.315   23
#
# [768 rows x 8 columns]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train, x_test, y_train, y_test = tts(x,y, test_size=.3, random_state=1)

# %%
dtc = dtree(criterion="entropy", splitter="best", max_depth=3)

# %%
dtc = dtc.fit(x_train, y_train)

# %%
y_pred = dtc.predict(x_test)

# %%
res= y_test - y_pred

# %%
res.value_counts()[0]/res.size
# Out:
# 0.7705627705627706

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7705627705627706

# %%
dot_data = StringIO()
export_graphviz(dtc, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = features,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())

# %%
l_x = x.to_numpy()

# %%
l_x[1]
# Out:
# array([ 1.   , 85.   , 66.   , 29.   ,  0.   , 26.6  ,  0.351, 31.   ])

# %%
len(l_x[:,2])
# Out:
# 768

# %%
plt.hist(l_x[:,7], bins=10)
# Out:
# (array([300., 157.,  92.,  86.,  52.,  34.,  26.,  16.,   4.,   1.]),
#  array([21., 27., 33., 39., 45., 51., 57., 63., 69., 75., 81.]),
#  <BarContainer object of 10 artists>)

# %%
np.sort(l_x[:,7])
# Out:
# array([21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21.,
#        21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21.,
#        21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21.,
#        21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21.,
#        21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 21., 22., 22.,
#        22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22.,
#        22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22.,
#        22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22.,
#        22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22.,
#        22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22., 22.,
#        22., 22., 22., 22., 22., 23., 23., 23., 23., 23., 23., 23., 23.,
#        23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 23.,
#        23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 23.,
# ...
